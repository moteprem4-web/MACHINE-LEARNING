# %%
import pandas as pd

# %%
data=pd.read_csv("/content/Employee_Dataset.csv")

# %%
data.head(5)
# Out:
#          Name  Age  Salary Gender    City   Mood
# 0  Employee_1   59  142719      F    Pune  Happy
# 1  Employee_2   49   50234      F  Nagpur    Sad
# 2  Employee_3   35   51381      F  Nagpur  Happy
# 3  Employee_4   28   47274      F   Delhi    Sad
# 4  Employee_5   41  142162      F  Nagpur    Sad

# %%
data.tail(5)
# Out:
#                 Name  Age  Salary Gender    City   Mood
# 9995   Employee_9996   44   52152      F  Mumbai  Happy
# 9996   Employee_9997   33  114738      F    Pune    Sad
# 9997   Employee_9998   49   56445      M    Pune  Happy
# 9998   Employee_9999   52  106688      M  Nashik    Sad
# 9999  Employee_10000   44  101153      F  Mumbai  Happy

# %%
data['Gender'].value_counts(['M'])
# Out:
# Gender
# F    0.5043
# M    0.4957
# Name: proportion, dtype: float64

# %%
# Out:
#                 Name  Age  Salary Gender    City   Mood
# 0         Employee_1   59  142719      F    Pune  Happy
# 1         Employee_2   49   50234      F  Nagpur    Sad
# 2         Employee_3   35   51381      F  Nagpur  Happy
# 3         Employee_4   28   47274      F   Delhi    Sad
# 4         Employee_5   41  142162      F  Nagpur    Sad
# ...              ...  ...     ...    ...     ...    ...
# 9995   Employee_9996   44   52152      F  Mumbai  Happy
# 9996   Employee_9997   33  114738      F    Pune    Sad
# 9997   Employee_9998   49   56445      M    Pune  Happy
# 9998   Employee_9999   52  106688      M  Nashik    Sad
# 9999  Employee_10000   44  101153      F  Mumbai  Happy
#
# [10000 rows x 6 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder

# %%
ct=ColumnTransformer(
    transformers=[
        ['num',StandardScaler(),['Age','Salary']],
        ["cat",OneHotEncoder(),['Gender','City']]
    ],
    remainder='passthrough'
)

# %%
ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[['num', StandardScaler(), ['Age', 'Salary']],
#                                 ['cat', OneHotEncoder(), ['Gender', 'City']]])

# %%
X_transformed = ct.fit_transform(data[['Salary', 'Age', 'City','Gender']])

# %%
X_transformed
# Out:
# array([[ 1.69408714,  1.54153462,  1.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.79951495, -1.11805389,  1.        , ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.45288612, -1.08506964,  1.        , ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.79951495, -0.93944434,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [ 1.06788661,  0.50539218,  0.        , ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.35222885,  0.34622234,  1.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
pipe=
# Out:
#                 Name  Age  Salary Gender    City   Mood
# 0         Employee_1   59  142719      F    Pune  Happy
# 1         Employee_2   49   50234      F  Nagpur    Sad
# 2         Employee_3   35   51381      F  Nagpur  Happy
# 3         Employee_4   28   47274      F   Delhi    Sad
# 4         Employee_5   41  142162      F  Nagpur    Sad
# ...              ...  ...     ...    ...     ...    ...
# 9995   Employee_9996   44   52152      F  Mumbai  Happy
# 9996   Employee_9997   33  114738      F    Pune    Sad
# 9997   Employee_9998   49   56445      M    Pune  Happy
# 9998   Employee_9999   52  106688      M  Nashik    Sad
# 9999  Employee_10000   44  101153      F  Mumbai  Happy
#
# [10000 rows x 6 columns]
